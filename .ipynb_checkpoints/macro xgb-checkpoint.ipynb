# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('C:\\Users\\zzuge\\trn_macro.csv')
val = pd.read_csv('C:\\Users\\zzuge\\vld_macro.csv')

# %%
train
# Out:
#         product_id  is_applied  credit_score  application_n  loyalty  gender  \
# 0              265           1           620             18        9       1
# 1              265           0           620             11        9       1
# 2              265           1           620             16        9       1
# 3              206           1           700              2        4       1
# 4              206           0           700              1        4       1
# ...            ...         ...           ...            ...      ...     ...
# 426450         270           0           910             33        0       1
# 426451         251           0           560              8        0       1
# 426452          75           1           610              1        3       0
# 426453          75           1           610              2        3       0
# 426454         243           1           630              3        2       1
#
# ...

# %%
val
# Out:
#         product_id  is_applied  credit_score  application_n  loyalty  gender  \
# 0              265           1           620             21        9       1
# 1              265           1           620             19        9       1
# 2              265           1           620             22        9       1
# 3              206           0           700              1        4       1
# 4              206           0           700              2        4       1
# ...            ...         ...           ...            ...      ...     ...
# 106845         262           0           930             15        0       1
# 106846         138           0           630              1        0       1
# 106847          61           1           680              2        1       1
# 106848         261           1           570              6        4       1
# 106849         257           1           600             14        2       0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train=train.drop(['product_id','is_applied'],axis=1)
y_train=train['is_applied']

x_val=val.drop(['product_id','is_applied'],axis=1)
y_val=val['is_applied']

# %%
x_train
# Out:
#         credit_score  application_n  loyalty  gender  log_yearly_income  \
# 0                620             18        9       1           6.301030
# 1                620             11        9       1           6.301030
# 2                620             16        9       1           6.301030
# 3                700              2        4       1           7.778151
# 4                700              1        4       1           7.778151
# ...              ...            ...      ...     ...                ...
# 426450           910             33        0       1           7.612784
# 426451           560              8        0       1           7.602060
# 426452           610              1        3       0           0.000000
# 426453           610              2        3       0           0.000000
# 426454           630              3        2       1           7.903090
#
#         log_career  log_desired_amount  log_existing_loan_cnt  \
# ...

# %%
y_train
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         0
#          ..
# 426450    0
# 426451    0
# 426452    1
# 426453    1
# 426454    1
# Name: is_applied, Length: 426455, dtype: int64

# %%
# !pip install xgboost

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(data=x_train, label=y_train)
dval = xgb.DMatrix(data=x_val, label=y_val)

# %%
params = {'max_depth' : 3,
         'eta' : 0.1, 
         'objective' : 'binary:logistic',
         'eval_metric' : 'error',
         'early_stoppings' : 100 }

# %%
xgb_model = xgb.train(params = params, dtrain = dtrain, num_boost_round = 400, 
                        early_stopping_rounds = 100, evals=[(dtrain,'train'),(dval,'eval')])
# Out:
# [11:04:34] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "early_stoppings" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-error:0.31541	eval-error:0.31380
# [1]	train-error:0.31252	eval-error:0.31087
# [2]	train-error:0.31079	eval-error:0.30892
# [3]	train-error:0.31114	eval-error:0.30898
# [4]	train-error:0.30661	eval-error:0.30435
# [5]	train-error:0.30636	eval-error:0.30430
# [6]	train-error:0.30319	eval-error:0.30099
# [7]	train-error:0.30596	eval-error:0.30380
# [8]	train-error:0.30619	eval-error:0.30403
# [9]	train-error:0.30248	eval-error:0.30012
# [10]	train-error:0.30191	eval-error:0.29952
# [11]	train-error:0.29897	eval-error:0.29739
# ...

# %%
y_pred_probs = xgb_model.predict(dval)

# %%
y_pred_probs
# Out:
# array([0.56178415, 0.5537954 , 0.56755143, ..., 0.70427215, 0.9277568 ,
#        0.8769543 ], dtype=float32)

# %%
y_pred = [1 if x>0.5 else 0 for x in y_pred_probs]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score

# %%
f1_score(y_val, y_pred)
# Out:
# 0.7593685270307072

# %%
precision_score(y_val, y_pred)
# Out:
# 0.7049891207747234

# %%
recall_score(y_val, y_pred)
# Out:
# 0.8228382366091389

# %%
accuracy_score(y_val, y_pred)
# Out:
# 0.7271034160037436

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_val, y_pred_probs)
plt.plot([0,1], [0,1], "k--", "r+")
plt.plot(fpr, tpr, label='xgb')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('xgb ROC curve')
plt.show()

# %%
roc=pd.DataFrame({'FPR':fpr,'TPR':tpr,'Threshold':thresholds})
optimal_idx=np.argmax(tpr-fpr)
optimal_thresholds=thresholds[optimal_idx]

# %%
optimal_thresholds
# Out:
# 0.5304317

# %%
from sklearn.metrics import roc_auc_score

rand_score = roc_auc_score(y_val, y_pred_probs)
rand_score
# Out:
# 0.8039642478902154

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgb_model, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
import statsmodels.api as sm

# %%
train.columns
# Out:
# Index(['product_id', 'is_applied', 'credit_score', 'application_n', 'loyalty',
#        'gender', 'log_yearly_income', 'log_career', 'log_desired_amount',
#        'log_existing_loan_cnt', 'log_existing_loan_amt', 'log_OpenApp',
#        'log_UseDSRCalc', 'nl_loan_limit', 'nl_loan_rate', 'nl_age',
#        'is_goodbank', 'is_goodprod', 'is_monday', 'is_weekend', 'is_after_16',
#        'is_earned_income1', 'is_earned_income2', 'is_job_regular',
#        'is_job_etc', 'is_house_own', 'is_house_lent', 'is_purpose_living',
#        'personal_rehabilitation_yn', 'personal_rehabilitation_complete_yn'],
#       dtype='object')

# %%
glm = sm.Logit.from_formula("is_applied ~ credit_score+application_n+loyalty+gender+log_yearly_income+log_career+log_desired_amount+log_existing_loan_cnt+log_existing_loan_amt+log_OpenApp+log_UseDSRCalc+nl_loan_limit+nl_loan_rate+nl_age+is_goodbank+is_goodprod+is_monday+is_weekend+is_after_16+is_earned_income1+is_earned_income2+is_job_regular+is_job_etc+is_house_own+is_house_lent+is_purpose_living+personal_rehabilitation_yn+personal_rehabilitation_complete_yn",train).fit()


print(glm.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.636250
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:             is_applied   No. Observations:               426455
# Model:                          Logit   Df Residuals:                   426426
# Method:                           MLE   Df Model:                           28
# Date:                Tue, 04 Oct 2022   Pseudo R-squ.:                 0.08084
# Time:                        20:03:14   Log-Likelihood:            -2.7133e+05
# converged:                       True   LL-Null:                   -2.9520e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...
