# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\zzuge\\df.csv',encoding='cp949')

# %%
link=pd.read_csv('C:\\Users\\zzuge\\link_dataframe.csv')

# %%
df
# Out:
#                                                  geometry     NODE_ID  \
# 0       Shapefile.Point(306862.5290999946, 364128.7581...  3680002100
# 1       Shapefile.Point(232175.56361976278, 428286.284...  1865949201
# 2       Shapefile.Point(262099.2841216855, 260200.9640...  3280218301
# 3       Shapefile.Point(261776.79685912761, 260206.480...  3280218201
# 4       Shapefile.Point(261777.6434585629, 259856.5594...  3280218101
# ...                                                   ...         ...
# 200897  Shapefile.Point(276681.37419968727, 311730.005...  3950099001
# 200898  Shapefile.Point(277172.98334151093, 313481.357...  3950099401
# 200899  Shapefile.Point(277185.10680105817, 313574.621...  3950099501
# 200900  Shapefile.Point(277198.45956309163, 313675.035...  3950099601
# 200901  Shapefile.Point(276486.0488271522, 313162.5098...  3950099301
#
#         NODE_TYPE  TURN_P  REMARK
# 0             101       0     NaN
# 1             101       0     NaN
# ...

# %%
df['geometry'][1][16:52]
# Out:
# '232175.56361976278, 428286.284158903'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200902 entries, 0 to 200901
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   geometry   200902 non-null  object
#  1   NODE_ID    200902 non-null  int64
#  2   NODE_TYPE  200902 non-null  int64
#  3   TURN_P     200902 non-null  int64
#  4   REMARK     3077 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 7.7+ MB

# %%
link
# Out:
#         Unnamed: 0     LINK_ID      F_NODE      T_NODE  LANES  ROAD_RANK  \
# 0                0  1860689001  1865963801  1865963701      2        107
# 1                1  1860688901  1865963701  1865963801      2        107
# 2                2  3280619601  3280218301  3280218501      2        107
# 3                3  3280619701  3280218501  3280218301      2        107
# 4                4  3280618801  3280218201  3280218101      2        107
# ...            ...         ...         ...         ...    ...        ...
# 540320      540320  3950263601  3950099601  3950099501      1        103
# 540321      540321  3950263901  3950007601  3950099601      2        103
# 540322      540322  3950263801  3950099601  3950007601      1        103
# 540323      540323  3950263201  3950099601  3950099301      1        107
# 540324      540324  3950263301  3950099301  3950099601      1        107
#
#         ROAD_TYPE ROAD_NO ROAD_NAME  ROAD_USE  MULTI_LINK  CONNECT  MAX_SPD  \
# ...

# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
import ast

# %%
topgun_g = nx.read_gexf('C:\\Users\\zzuge\\df.csv')
# Out:
# Traceback (most recent call last):
#
#   File ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [5] in <cell line: 1>
#     topgun_g = nx.read_gexf('C:\\Users\\zzuge\\df.csv')
#
#   File ~\Anaconda3\lib\site-packages\networkx\utils\decorators.py:816 in func
#     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
#   File <class 'networkx.utils.decorators.argmap'> compilation 5:5 in argmap_read_gexf_1
#
#   File ~\Anaconda3\lib\site-packages\networkx\readwrite\gexf.py:176 in read_gexf
#     G = reader(path)
#
#   File ~\Anaconda3\lib\site-packages\networkx\readwrite\gexf.py:693 in __call__
#     self.xml = ElementTree(file=stream)
#
#   File ~\Anaconda3\lib\xml\etree\ElementTree.py:540 in __init__
#     self.parse(file)
#
#   File ~\Anaconda3\lib\xml\etree\ElementTree.py:580 in parse
#     self._root = parser._parse_whole(source)
#
#   File <string>
# ...
